# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2 = pd.read_csv("animelists_cleaned.csv")
df2_v2 = df2[['username','anime_id','my_watched_episodes','my_score','my_status']]
df2_v2
# Out:
#                   username  anime_id  my_watched_episodes  my_score  my_status
# 0                 karthiga        21                  586         9          1
# 1                 karthiga        59                   26         7          2
# 2                 karthiga        74                   26         7          2
# 3                 karthiga       120                   26         7          2
# 4                 karthiga       178                   26         7          2
# ...                    ...       ...                  ...       ...        ...
# 31284025     Yokonightcore     15611                   48         9          1
# 31284026     Yokonightcore     27815                   22         9          1
# 31284027            wargod      5945                   39         8          2
# 31284028  JMc_SetoKai_LoVe      1316                   52         9          2
# 31284029    hinogurl_mikha      1744                   58        10          1
#
# [31284030 rows x 5 columns]

# %%
df3 = pd.read_csv("anime_cleaned.csv")
df3_v2 = df3[["anime_id",'title','genre','source','popularity','rank','type','episodes','favorites']]
df3_v2
# Out:
#       anime_id                                              title  \
# 0        11013                                      Inu x Boku SS
# 1         2104                                   Seto no Hanayome
# 2         5262                                 Shugo Chara!! Doki
# 3          721                                      Princess Tutu
# 4        12365                                Bakuman. 3rd Season
# ...        ...                                                ...
# 6663     37405                            Dokidoki Little Ooyasan
# 6664     37886                        Wo Shi Jiang Xiaobai (2018)
# 6665     37255              Genki Genki Non-tan: Obake Mura Meiro
# 6666     35229                                Mr. Men Little Miss
# 6667     36315  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...
#
#                                          genre        source  popularity  \
# 0       Comedy, Supernatural, Romance, Shounen         Manga         231
# 1     Comedy, Parody, Romance, School, Shounen         Manga         366
# 2                Comedy, Magic, School, Shoujo         Manga        1173
# 3       Comedy, Drama, Magic, Romance, Fantasy      Original         916
# 4              Comedy, Drama, Romance, Shounen         Manga         426
# ...                                        ...           ...         ...
# 6663                                    Hentai         Other       10273
# 6664             Slice of Life, Drama, Romance      Original       10168
# 6665                               Music, Kids      Original       14257
# 6666                                      Kids  Picture book       14066
# 6667                                      Kids      Original       14191
#
#          rank type  episodes  favorites
# 0      1274.0   TV        12       2809
# 1       727.0   TV        26       2579
# 2      1508.0   TV        51        802
# 3       307.0   TV        38       3344
# 4        50.0   TV        25       2082
# ...       ...  ...       ...        ...
# 6663      NaN  OVA         0         21
# 6664  12719.0  ONA         1          1
# 6665  10253.0  OVA         1          0
# 6666  11396.0  ONA         0          1
# 6667  11396.0  OVA         1          0
#
# [6668 rows x 9 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6668 entries, 0 to 6667
# Data columns (total 33 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   anime_id         6668 non-null   int64
#  1   title            6668 non-null   object
#  2   title_english    3438 non-null   object
#  3   title_japanese   6663 non-null   object
#  4   title_synonyms   4481 non-null   object
#  5   image_url        6666 non-null   object
#  6   type             6668 non-null   object
#  7   source           6668 non-null   object
#  8   episodes         6668 non-null   int64
#  9   status           6668 non-null   object
#  10  airing           6668 non-null   bool
#  11  aired_string     6668 non-null   object
#  12  aired            6668 non-null   object
#  13  duration         6668 non-null   object
#  14  rating           6668 non-null   object
#  15  score            6668 non-null   float64
#  16  scored_by        6668 non-null   int64
#  17  rank             6312 non-null   float64
#  18  popularity       6668 non-null   int64
#  19  members          6668 non-null   int64
#  20  favorites        6668 non-null   int64
#  21  background       813 non-null    object
#  22  premiered        2966 non-null   object
#  23  broadcast        2980 non-null   object
#  24  related          6668 non-null   object
#  25  producer         4402 non-null   object
#  26  licensor         2787 non-null   object
#  27  studio           6668 non-null   object
#  28  genre            6664 non-null   object
#  29  opening_theme    6668 non-null   object
#  30  ending_theme     6668 non-null   object
#  31  duration_min     6668 non-null   float64
#  32  aired_from_year  6668 non-null   float64
# dtypes: bool(1), float64(4), int64(6), object(22)
# memory usage: 1.6+ MB

# %%
df4 = pd.read_csv("UserList.csv")
df4_v2 = df4[['username','user_id']]

# %%
merged_df = pd.merge(df2_v2 , df3_v2, on='anime_id', how = 'right')

# %%
merged_df
# Out:
#                username  anime_id  my_watched_episodes  my_score  my_status  \
# 0              karthiga     11013                   12         8          2
# 1                Slimak     11013                    0         0          6
# 2         MistButterfly     11013                   12         7          2
# 3             Lithuelle     11013                    0         0          6
# 4            magedgamed     11013                   12         7          2
# ...                 ...       ...                  ...       ...        ...
# 31284025      axios1331     35229                    0         0          1
# 31284026         Exxorn     35229                    0         0          6
# 31284027        uemmega     36315                    0         0          6
# 31284028  anime2music21     36315                    0         0          6
# 31284029         Azurii     36315                    0         0          6
#
#                                                       title  \
# 0                                             Inu x Boku SS
# 1                                             Inu x Boku SS
# 2                                             Inu x Boku SS
# 3                                             Inu x Boku SS
# 4                                             Inu x Boku SS
# ...                                                     ...
# 31284025                                Mr. Men Little Miss
# 31284026                                Mr. Men Little Miss
# 31284027  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...
# 31284028  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...
# 31284029  Mushi Mushi Mura no Nakama-tachi: Minna Ii Tok...
#
#                                            genre        source  popularity  \
# 0         Comedy, Supernatural, Romance, Shounen         Manga         231
# 1         Comedy, Supernatural, Romance, Shounen         Manga         231
# 2         Comedy, Supernatural, Romance, Shounen         Manga         231
# 3         Comedy, Supernatural, Romance, Shounen         Manga         231
# 4         Comedy, Supernatural, Romance, Shounen         Manga         231
# ...                                          ...           ...         ...
# 31284025                                    Kids  Picture book       14066
# 31284026                                    Kids  Picture book       14066
# 31284027                                    Kids      Original       14191
# 31284028                                    Kids      Original       14191
# 31284029                                    Kids      Original       14191
#
#              rank type  episodes  favorites
# 0          1274.0   TV        12       2809
# 1          1274.0   TV        12       2809
# 2          1274.0   TV        12       2809
# 3          1274.0   TV        12       2809
# 4          1274.0   TV        12       2809
# ...           ...  ...       ...        ...
# 31284025  11396.0  ONA         0          1
# 31284026  11396.0  ONA         0          1
# 31284027  11396.0  OVA         1          0
# 31284028  11396.0  OVA         1          0
# 31284029  11396.0  OVA         1          0
#
# [31284030 rows x 13 columns]

# %%
merged_df2 = pd.merge(merged_df, df4_v2, on = "username", how = "right")
merged_df2
# Out:
#             username  anime_id  my_watched_episodes  my_score  my_status  \
# 0           karthiga   11013.0                 12.0       8.0        2.0
# 1           karthiga    2104.0                 26.0       7.0        2.0
# 2           karthiga    5262.0                 51.0       7.0        2.0
# 3           karthiga     721.0                 38.0       7.0        2.0
# 4           karthiga   12365.0                 25.0       8.0        2.0
# ...              ...       ...                  ...       ...        ...
# 31477990      HMicca    1363.0                  1.0       9.0        2.0
# 31477991      HMicca     889.0                 12.0       9.0        2.0
# 31477992      HMicca     122.0                 52.0       9.0        2.0
# 31477993      HMicca    1110.0                 39.0       8.0        2.0
# 31477994  mini_kaila       NaN                  NaN       NaN        NaN
#
#                                                    title  \
# 0                                          Inu x Boku SS
# 1                                       Seto no Hanayome
# 2                                     Shugo Chara!! Doki
# 3                                          Princess Tutu
# 4                                    Bakuman. 3rd Season
# ...                                                  ...
# 31477990  Detective Conan Movie 04: Captured in Her Eyes
# 31477991                                    Black Lagoon
# 31477992                          Full Moon wo Sagashite
# 31477993           Mermaid Melody Pichi Pichi Pitch Pure
# 31477994                                             NaN
#
#                                                       genre    source  \
# 0                    Comedy, Supernatural, Romance, Shounen     Manga
# 1                  Comedy, Parody, Romance, School, Shounen     Manga
# 2                             Comedy, Magic, School, Shoujo     Manga
# 3                    Comedy, Drama, Magic, Romance, Fantasy  Original
# 4                           Comedy, Drama, Romance, Shounen     Manga
# ...                                                     ...       ...
# 31477990        Adventure, Mystery, Comedy, Police, Shounen     Manga
# 31477991                                     Action, Seinen     Manga
# 31477992  Music, Comedy, Supernatural, Drama, Romance, S...     Manga
# 31477993          Adventure, Comedy, Magic, Romance, Shoujo     Manga
# 31477994                                                NaN       NaN
#
#           popularity    rank   type  episodes  favorites  user_id
# 0              231.0  1274.0     TV      12.0     2809.0  2255153
# 1              366.0   727.0     TV      26.0     2579.0  2255153
# 2             1173.0  1508.0     TV      51.0      802.0  2255153
# 3              916.0   307.0     TV      38.0     3344.0  2255153
# 4              426.0    50.0     TV      25.0     2082.0  2255153
# ...              ...     ...    ...       ...        ...      ...
# 31477990      1993.0   367.0  Movie       1.0       54.0  1289601
# 31477991        98.0   394.0     TV      12.0     9708.0  1289601
# 31477992      1158.0   489.0     TV      52.0     1569.0  1289601
# 31477993      2417.0  2893.0     TV      39.0      212.0  1289601
# 31477994         NaN     NaN    NaN       NaN        NaN   236339
#
# [31477995 rows x 14 columns]

# %%
merged_df2.isnull().sum()
# Out:
# username                  243
# anime_id               193965
# my_watched_episodes    193965
# my_score               193965
# my_status              193965
# title                  193965
# genre                  195673
# source                 193965
# popularity             193965
# rank                   547340
# type                   193965
# episodes               193965
# favorites              193965
# user_id                     0
# dtype: int64

# %%
merged_df2 = merged_df2.dropna()
merged_df2.isnull().sum()
# Out:
# username               0
# anime_id               0
# my_watched_episodes    0
# my_score               0
# my_status              0
# title                  0
# genre                  0
# source                 0
# popularity             0
# rank                   0
# type                   0
# episodes               0
# favorites              0
# user_id                0
# dtype: int64

# %%
merged_df2
# Out:
#           username  anime_id  my_watched_episodes  my_score  my_status  \
# 0         karthiga   11013.0                 12.0       8.0        2.0
# 1         karthiga    2104.0                 26.0       7.0        2.0
# 2         karthiga    5262.0                 51.0       7.0        2.0
# 3         karthiga     721.0                 38.0       7.0        2.0
# 4         karthiga   12365.0                 25.0       8.0        2.0
# ...            ...       ...                  ...       ...        ...
# 31477989    HMicca     469.0                 24.0       8.0        2.0
# 31477990    HMicca    1363.0                  1.0       9.0        2.0
# 31477991    HMicca     889.0                 12.0       9.0        2.0
# 31477992    HMicca     122.0                 52.0       9.0        2.0
# 31477993    HMicca    1110.0                 39.0       8.0        2.0
#
#                                                    title  \
# 0                                          Inu x Boku SS
# 1                                       Seto no Hanayome
# 2                                     Shugo Chara!! Doki
# 3                                          Princess Tutu
# 4                                    Bakuman. 3rd Season
# ...                                                  ...
# 31477989                                           Karin
# 31477990  Detective Conan Movie 04: Captured in Her Eyes
# 31477991                                    Black Lagoon
# 31477992                          Full Moon wo Sagashite
# 31477993           Mermaid Melody Pichi Pichi Pitch Pure
#
#                                                       genre    source  \
# 0                    Comedy, Supernatural, Romance, Shounen     Manga
# 1                  Comedy, Parody, Romance, School, Shounen     Manga
# 2                             Comedy, Magic, School, Shoujo     Manga
# 3                    Comedy, Drama, Magic, Romance, Fantasy  Original
# 4                           Comedy, Drama, Romance, Shounen     Manga
# ...                                                     ...       ...
# 31477989          Comedy, Romance, Vampire, School, Shounen     Manga
# 31477990        Adventure, Mystery, Comedy, Police, Shounen     Manga
# 31477991                                     Action, Seinen     Manga
# 31477992  Music, Comedy, Supernatural, Drama, Romance, S...     Manga
# 31477993          Adventure, Comedy, Magic, Romance, Shoujo     Manga
#
#           popularity    rank   type  episodes  favorites  user_id
# 0              231.0  1274.0     TV      12.0     2809.0  2255153
# 1              366.0   727.0     TV      26.0     2579.0  2255153
# 2             1173.0  1508.0     TV      51.0      802.0  2255153
# 3              916.0   307.0     TV      38.0     3344.0  2255153
# 4              426.0    50.0     TV      25.0     2082.0  2255153
# ...              ...     ...    ...       ...        ...      ...
# 31477989       674.0  2491.0     TV      24.0      773.0  1289601
# 31477990      1993.0   367.0  Movie       1.0       54.0  1289601
# 31477991        98.0   394.0     TV      12.0     9708.0  1289601
# 31477992      1158.0   489.0     TV      52.0     1569.0  1289601
# 31477993      2417.0  2893.0     TV      39.0      212.0  1289601
#
# [30928704 rows x 14 columns]

# %%
merged_df2.corr()
# Out:
# /var/folders/y7/b9q8qz9942vb03jb76_vv3s80000gn/T/ipykernel_40806/2870213408.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   merged_df2.corr()
#                      anime_id  my_watched_episodes  my_score  my_status  \
# anime_id             1.000000            -0.128624 -0.060151   0.000680
# my_watched_episodes -0.128624             1.000000  0.188293  -0.198693
# my_score            -0.060151             0.188293  1.000000  -0.651664
# my_status            0.000680            -0.198693 -0.651664   1.000000
# popularity          -0.025790            -0.119334 -0.155379   0.114748
# rank                 0.098229            -0.114861 -0.160509   0.056776
# episodes            -0.157390             0.631294  0.022960  -0.015488
# favorites           -0.105734             0.286209  0.128265  -0.075415
# user_id              0.311576            -0.020133 -0.069406   0.092484
#
#                      popularity      rank  episodes  favorites   user_id
# anime_id              -0.025790  0.098229 -0.157390  -0.105734  0.311576
# my_watched_episodes   -0.119334 -0.114861  0.631294   0.286209 -0.020133
# my_score              -0.155379 -0.160509  0.022960   0.128265 -0.069406
# my_status              0.114748  0.056776 -0.015488  -0.075415  0.092484
# popularity             1.000000  0.552447 -0.115373  -0.321933 -0.095402
# rank                   0.552447  1.000000 -0.131467  -0.331757 -0.036064
# episodes              -0.115373 -0.131467  1.000000   0.276435 -0.017428
# favorites             -0.321933 -0.331757  0.276435   1.000000  0.037688
# user_id               -0.095402 -0.036064 -0.017428   0.037688  1.000000

# %% [markdown]
# high correlation
# my_watched_episodes and episodes
#
# popularity and favourites
#
# popularity and rank

# %%
small_df = merged_df2.sample(frac = 0.0001) #My macbook can't handle 30Million hahaha so I've cut down but feel free to change back when using desktop
small_df
# Out:
#               username  anime_id  my_watched_episodes  my_score  my_status  \
# 3427358       burucchi   11703.0                 13.0       6.0        2.0
# 2879863      veryberry     513.0                  0.0       8.0        6.0
# 5326017        Yandols   11079.0                  3.0       9.0        1.0
# 5665658           Jheo    9989.0                 11.0      10.0        2.0
# 25432477    AdioCapone      97.0                  0.0       0.0        6.0
# ...                ...       ...                  ...       ...        ...
# 14358396        Trojer    5081.0                 11.0       0.0        4.0
# 20629596         laoil    6401.0                  1.0       0.0        2.0
# 26988649        Kur0ai   31483.0                  1.0       7.0        2.0
# 28144306         VGE3K     226.0                 13.0       8.0        2.0
# 7848177   Akira_Sakura    6547.0                 13.0       4.0        2.0
#
#                                                       title  \
# 3427358                                        Code:Breaker
# 2879863                              Tenkuu no Shiro Laputa
# 5326017                                        Kill Me Baby
# 5665658   Ano Hi Mita Hana no Namae wo Bokutachi wa Mada...
# 25432477                                         Last Exile
# ...                                                     ...
# 14358396                                     Bakemonogatari
# 20629596                 ef: A Tale of Melodies. - Prologue
# 26988649  Akagami no Shirayuki-hime: Nandemonai Takaramo...
# 28144306                                         Elfen Lied
# 7848177                                        Angel Beats!
#
#                                                       genre        source  \
# 3427358   Action, Comedy, School, Shounen, Super Power, ...         Manga
# 2879863                 Adventure, Fantasy, Romance, Sci-Fi      Original
# 5326017                              Comedy, School, Seinen  4-koma manga
# 5665658                  Slice of Life, Supernatural, Drama      Original
# 25432477                          Action, Sci-Fi, Adventure      Original
# ...                                                     ...           ...
# 14358396            Romance, Supernatural, Mystery, Vampire   Light novel
# 20629596                                              Music  Visual novel
# 26988649                    Drama, Fantasy, Romance, Shoujo         Manga
# 28144306  Action, Horror, Psychological, Supernatural, D...         Manga
# 7848177         Action, Comedy, Drama, School, Supernatural      Original
#
#           popularity    rank     type  episodes  favorites  user_id
# 3427358        437.0  3631.0       TV      13.0      508.0   135745
# 2879863        364.0   179.0    Movie       1.0     1811.0   450053
# 5326017       1168.0  3779.0       TV      13.0      321.0   324788
# 5665658         45.0    81.0       TV      11.0    21155.0  1690283
# 25432477       689.0   699.0       TV      26.0     1668.0   271523
# ...              ...     ...      ...       ...        ...      ...
# 14358396        44.0   191.0       TV      15.0    27088.0  5661345
# 20629596      3035.0  2107.0  Special       1.0       14.0   486647
# 26988649      1956.0   892.0      OVA       1.0       90.0  1830099
# 28144306        16.0   982.0       TV      13.0    20137.0  1505347
# 7848177          7.0   227.0       TV      13.0    36456.0  3840719
#
# [3093 rows x 14 columns]

# %%
small_df['source'].value_counts()
# Out:
# Manga            1332
# Original          581
# Light novel       547
# Visual novel      180
# Novel             130
# Game              119
# 4-koma manga       85
# Web manga          42
# Other              40
# Card game          14
# Music              12
# Book                8
# Picture book        2
# Digital manga       1
# Name: source, dtype: int64

# %%
small_df2 = small_df.drop(['username'], axis = 1)

# %%
small_df2
# Out:
#           anime_id  my_watched_episodes  my_score  my_status  \
# 3427358    11703.0                 13.0       6.0        2.0
# 2879863      513.0                  0.0       8.0        6.0
# 5326017    11079.0                  3.0       9.0        1.0
# 5665658     9989.0                 11.0      10.0        2.0
# 25432477      97.0                  0.0       0.0        6.0
# ...            ...                  ...       ...        ...
# 14358396    5081.0                 11.0       0.0        4.0
# 20629596    6401.0                  1.0       0.0        2.0
# 26988649   31483.0                  1.0       7.0        2.0
# 28144306     226.0                 13.0       8.0        2.0
# 7848177     6547.0                 13.0       4.0        2.0
#
#                                                       title  \
# 3427358                                        Code:Breaker
# 2879863                              Tenkuu no Shiro Laputa
# 5326017                                        Kill Me Baby
# 5665658   Ano Hi Mita Hana no Namae wo Bokutachi wa Mada...
# 25432477                                         Last Exile
# ...                                                     ...
# 14358396                                     Bakemonogatari
# 20629596                 ef: A Tale of Melodies. - Prologue
# 26988649  Akagami no Shirayuki-hime: Nandemonai Takaramo...
# 28144306                                         Elfen Lied
# 7848177                                        Angel Beats!
#
#                                                       genre        source  \
# 3427358   Action, Comedy, School, Shounen, Super Power, ...         Manga
# 2879863                 Adventure, Fantasy, Romance, Sci-Fi      Original
# 5326017                              Comedy, School, Seinen  4-koma manga
# 5665658                  Slice of Life, Supernatural, Drama      Original
# 25432477                          Action, Sci-Fi, Adventure      Original
# ...                                                     ...           ...
# 14358396            Romance, Supernatural, Mystery, Vampire   Light novel
# 20629596                                              Music  Visual novel
# 26988649                    Drama, Fantasy, Romance, Shoujo         Manga
# 28144306  Action, Horror, Psychological, Supernatural, D...         Manga
# 7848177         Action, Comedy, Drama, School, Supernatural      Original
#
#           popularity    rank     type  episodes  favorites  user_id
# 3427358        437.0  3631.0       TV      13.0      508.0   135745
# 2879863        364.0   179.0    Movie       1.0     1811.0   450053
# 5326017       1168.0  3779.0       TV      13.0      321.0   324788
# 5665658         45.0    81.0       TV      11.0    21155.0  1690283
# 25432477       689.0   699.0       TV      26.0     1668.0   271523
# ...              ...     ...      ...       ...        ...      ...
# 14358396        44.0   191.0       TV      15.0    27088.0  5661345
# 20629596      3035.0  2107.0  Special       1.0       14.0   486647
# 26988649      1956.0   892.0      OVA       1.0       90.0  1830099
# 28144306        16.0   982.0       TV      13.0    20137.0  1505347
# 7848177          7.0   227.0       TV      13.0    36456.0  3840719
#
# [3093 rows x 13 columns]

# %%
small_df2['type'].value_counts()
# Out:
# TV         2184
# Movie       402
# OVA         269
# Special     181
# ONA          51
# Music         6
# Name: type, dtype: int64

# %%
small_df3 = small_df2.drop('title', axis=1)

# %%
small_df3
# Out:
#           anime_id  my_watched_episodes  my_score  my_status  \
# 3427358    11703.0                 13.0       6.0        2.0
# 2879863      513.0                  0.0       8.0        6.0
# 5326017    11079.0                  3.0       9.0        1.0
# 5665658     9989.0                 11.0      10.0        2.0
# 25432477      97.0                  0.0       0.0        6.0
# ...            ...                  ...       ...        ...
# 14358396    5081.0                 11.0       0.0        4.0
# 20629596    6401.0                  1.0       0.0        2.0
# 26988649   31483.0                  1.0       7.0        2.0
# 28144306     226.0                 13.0       8.0        2.0
# 7848177     6547.0                 13.0       4.0        2.0
#
#                                                       genre        source  \
# 3427358   Action, Comedy, School, Shounen, Super Power, ...         Manga
# 2879863                 Adventure, Fantasy, Romance, Sci-Fi      Original
# 5326017                              Comedy, School, Seinen  4-koma manga
# 5665658                  Slice of Life, Supernatural, Drama      Original
# 25432477                          Action, Sci-Fi, Adventure      Original
# ...                                                     ...           ...
# 14358396            Romance, Supernatural, Mystery, Vampire   Light novel
# 20629596                                              Music  Visual novel
# 26988649                    Drama, Fantasy, Romance, Shoujo         Manga
# 28144306  Action, Horror, Psychological, Supernatural, D...         Manga
# 7848177         Action, Comedy, Drama, School, Supernatural      Original
#
#           popularity    rank     type  episodes  favorites  user_id
# 3427358        437.0  3631.0       TV      13.0      508.0   135745
# 2879863        364.0   179.0    Movie       1.0     1811.0   450053
# 5326017       1168.0  3779.0       TV      13.0      321.0   324788
# 5665658         45.0    81.0       TV      11.0    21155.0  1690283
# 25432477       689.0   699.0       TV      26.0     1668.0   271523
# ...              ...     ...      ...       ...        ...      ...
# 14358396        44.0   191.0       TV      15.0    27088.0  5661345
# 20629596      3035.0  2107.0  Special       1.0       14.0   486647
# 26988649      1956.0   892.0      OVA       1.0       90.0  1830099
# 28144306        16.0   982.0       TV      13.0    20137.0  1505347
# 7848177          7.0   227.0       TV      13.0    36456.0  3840719
#
# [3093 rows x 12 columns]

# %%
# Create a list of unique genre labels
genres = set([genre for row in small_df3['genre'].str.split(', ') for genre in row])

# One Hot Encoding
for genre in genres:
    small_df3[genre] = small_df3['genre'].apply(lambda x: 1 if genre in x.split(', ') else 0)

# Drop the original 'genre' column
small_df3.drop('genre', axis=1, inplace=True)

small_df4 = pd.concat([small_df3.iloc[:,:11], small_df3.iloc[:, -len(genres):]], axis=1)
small_df4
# Out:
#           anime_id  my_watched_episodes  my_score  my_status        source  \
# 3427358    11703.0                 13.0       6.0        2.0         Manga
# 2879863      513.0                  0.0       8.0        6.0      Original
# 5326017    11079.0                  3.0       9.0        1.0  4-koma manga
# 5665658     9989.0                 11.0      10.0        2.0      Original
# 25432477      97.0                  0.0       0.0        6.0      Original
# ...            ...                  ...       ...        ...           ...
# 14358396    5081.0                 11.0       0.0        4.0   Light novel
# 20629596    6401.0                  1.0       0.0        2.0  Visual novel
# 26988649   31483.0                  1.0       7.0        2.0         Manga
# 28144306     226.0                 13.0       8.0        2.0         Manga
# 7848177     6547.0                 13.0       4.0        2.0      Original
#
#           popularity    rank     type  episodes  favorites  ...  Dementia  \
# 3427358        437.0  3631.0       TV      13.0      508.0  ...         0
# 2879863        364.0   179.0    Movie       1.0     1811.0  ...         0
# 5326017       1168.0  3779.0       TV      13.0      321.0  ...         0
# 5665658         45.0    81.0       TV      11.0    21155.0  ...         0
# 25432477       689.0   699.0       TV      26.0     1668.0  ...         0
# ...              ...     ...      ...       ...        ...  ...       ...
# 14358396        44.0   191.0       TV      15.0    27088.0  ...         0
# 20629596      3035.0  2107.0  Special       1.0       14.0  ...         0
# 26988649      1956.0   892.0      OVA       1.0       90.0  ...         0
# 28144306        16.0   982.0       TV      13.0    20137.0  ...         0
# 7848177          7.0   227.0       TV      13.0    36456.0  ...         0
#
#           School  Shounen  Shoujo  Josei  Music  Shounen Ai  Romance  Fantasy  \
# 3427358        1        1       0      0      0           0        0        0
# 2879863        0        0       0      0      0           0        1        1
# 5326017        1        0       0      0      0           0        0        0
# 5665658        0        0       0      0      0           0        0        0
# 25432477       0        0       0      0      0           0        0        0
# ...          ...      ...     ...    ...    ...         ...      ...      ...
# 14358396       0        0       0      0      0           0        1        0
# 20629596       0        0       0      0      1           0        0        0
# 26988649       0        0       1      0      0           0        1        1
# 28144306       0        0       0      0      0           0        1        0
# 7848177        1        0       0      0      0           0        0        0
#
#           Harem
# 3427358       0
# 2879863       0
# 5326017       0
# 5665658       0
# 25432477      0
# ...         ...
# 14358396      0
# 20629596      0
# 26988649      0
# 28144306      0
# 7848177       0
#
# [3093 rows x 51 columns]

# %%
small_df4
# Out:
#           anime_id  my_watched_episodes  my_score  my_status        source  \
# 3427358    11703.0                 13.0       6.0        2.0         Manga
# 2879863      513.0                  0.0       8.0        6.0      Original
# 5326017    11079.0                  3.0       9.0        1.0  4-koma manga
# 5665658     9989.0                 11.0      10.0        2.0      Original
# 25432477      97.0                  0.0       0.0        6.0      Original
# ...            ...                  ...       ...        ...           ...
# 14358396    5081.0                 11.0       0.0        4.0   Light novel
# 20629596    6401.0                  1.0       0.0        2.0  Visual novel
# 26988649   31483.0                  1.0       7.0        2.0         Manga
# 28144306     226.0                 13.0       8.0        2.0         Manga
# 7848177     6547.0                 13.0       4.0        2.0      Original
#
#           popularity    rank     type  episodes  favorites  ...  Dementia  \
# 3427358        437.0  3631.0       TV      13.0      508.0  ...         0
# 2879863        364.0   179.0    Movie       1.0     1811.0  ...         0
# 5326017       1168.0  3779.0       TV      13.0      321.0  ...         0
# 5665658         45.0    81.0       TV      11.0    21155.0  ...         0
# 25432477       689.0   699.0       TV      26.0     1668.0  ...         0
# ...              ...     ...      ...       ...        ...  ...       ...
# 14358396        44.0   191.0       TV      15.0    27088.0  ...         0
# 20629596      3035.0  2107.0  Special       1.0       14.0  ...         0
# 26988649      1956.0   892.0      OVA       1.0       90.0  ...         0
# 28144306        16.0   982.0       TV      13.0    20137.0  ...         0
# 7848177          7.0   227.0       TV      13.0    36456.0  ...         0
#
#           School  Shounen  Shoujo  Josei  Music  Shounen Ai  Romance  Fantasy  \
# 3427358        1        1       0      0      0           0        0        0
# 2879863        0        0       0      0      0           0        1        1
# 5326017        1        0       0      0      0           0        0        0
# 5665658        0        0       0      0      0           0        0        0
# 25432477       0        0       0      0      0           0        0        0
# ...          ...      ...     ...    ...    ...         ...      ...      ...
# 14358396       0        0       0      0      0           0        1        0
# 20629596       0        0       0      0      1           0        0        0
# 26988649       0        0       1      0      0           0        1        1
# 28144306       0        0       0      0      0           0        1        0
# 7848177        1        0       0      0      0           0        0        0
#
#           Harem
# 3427358       0
# 2879863       0
# 5326017       0
# 5665658       0
# 25432477      0
# ...         ...
# 14358396      0
# 20629596      0
# 26988649      0
# 28144306      0
# 7848177       0
#
# [3093 rows x 51 columns]

# %%
sns.scatterplot(data = small_df4, x = 'my_score', y ='episodes')
# Out:
# <AxesSubplot: xlabel='my_score', ylabel='episodes'>

# %%
sns.scatterplot(data = small_df4, x = 'my_watched_episodes', y='episodes')
# Out:
# <AxesSubplot: xlabel='my_watched_episodes', ylabel='episodes'>

# %%
small_df4[['type']].value_counts()
# Out:
# type
# TV         2184
# Movie       402
# OVA         269
# Special     181
# ONA          51
# Music         6
# dtype: int64

# %%
import pandas as pd

#One Hot Encoding
type_dummies = pd.get_dummies(small_df4['type'])

small_df5 = pd.concat([small_df4, type_dummies], axis=1)

# Drop the original 'genre' column
small_df5.drop('type', axis=1, inplace=True)
small_df5
# Out:
#           anime_id  my_watched_episodes  my_score  my_status        source  \
# 3427358    11703.0                 13.0       6.0        2.0         Manga
# 2879863      513.0                  0.0       8.0        6.0      Original
# 5326017    11079.0                  3.0       9.0        1.0  4-koma manga
# 5665658     9989.0                 11.0      10.0        2.0      Original
# 25432477      97.0                  0.0       0.0        6.0      Original
# ...            ...                  ...       ...        ...           ...
# 14358396    5081.0                 11.0       0.0        4.0   Light novel
# 20629596    6401.0                  1.0       0.0        2.0  Visual novel
# 26988649   31483.0                  1.0       7.0        2.0         Manga
# 28144306     226.0                 13.0       8.0        2.0         Manga
# 7848177     6547.0                 13.0       4.0        2.0      Original
#
#           popularity    rank  episodes  favorites  user_id  ...  Shounen Ai  \
# 3427358        437.0  3631.0      13.0      508.0   135745  ...           0
# 2879863        364.0   179.0       1.0     1811.0   450053  ...           0
# 5326017       1168.0  3779.0      13.0      321.0   324788  ...           0
# 5665658         45.0    81.0      11.0    21155.0  1690283  ...           0
# 25432477       689.0   699.0      26.0     1668.0   271523  ...           0
# ...              ...     ...       ...        ...      ...  ...         ...
# 14358396        44.0   191.0      15.0    27088.0  5661345  ...           0
# 20629596      3035.0  2107.0       1.0       14.0   486647  ...           0
# 26988649      1956.0   892.0       1.0       90.0  1830099  ...           0
# 28144306        16.0   982.0      13.0    20137.0  1505347  ...           0
# 7848177          7.0   227.0      13.0    36456.0  3840719  ...           0
#
#           Romance  Fantasy  Harem  Movie  Music  ONA  OVA  Special  TV
# 3427358         0        0      0      0      0    0    0        0   1
# 2879863         1        1      0      1      0    0    0        0   0
# 5326017         0        0      0      0      0    0    0        0   1
# 5665658         0        0      0      0      0    0    0        0   1
# 25432477        0        0      0      0      0    0    0        0   1
# ...           ...      ...    ...    ...    ...  ...  ...      ...  ..
# 14358396        1        0      0      0      0    0    0        0   1
# 20629596        0        0      0      0      0    0    0        1   0
# 26988649        1        1      0      0      0    0    1        0   0
# 28144306        1        0      0      0      0    0    0        0   1
# 7848177         0        0      0      0      0    0    0        0   1
#
# [3093 rows x 56 columns]

# %%
small_df4[['source']].value_counts()
# Out:
# source
# Manga            1332
# Original          581
# Light novel       547
# Visual novel      180
# Novel             130
# Game              119
# 4-koma manga       85
# Web manga          42
# Other              40
# Card game          14
# Music              12
# Book                8
# Picture book        2
# Digital manga       1
# dtype: int64

# %%
import gensim

# Using Word2Vec on the source column
sources = [source.split(", ") for source in small_df5["source"]]

model = gensim.models.Word2Vec(sources, vector_size=100, min_count=1)


source_dict = {}
for source in set(small_df5["source"]):
    source_dict[source] = model.wv[source.split(", ")[0]]

# Create a new dataframe 
source_df = small_df4[["anime_id", "source"]].copy()
source_df["source_vector"] = source_df["source"].apply(lambda x: model.wv[x.split(", ")[0]])
source_df = pd.concat([source_df[["anime_id", "source_vector"]], source_df["source_vector"].apply(pd.Series)], axis=1)

anime_df = pd.merge(small_df5.drop(columns=["source"]), source_df, on="anime_id")

# %%
anime_df
# Out:
#       anime_id  my_watched_episodes  my_score  my_status  popularity    rank  \
# 0      11703.0                 13.0       6.0        2.0       437.0  3631.0
# 1      11703.0                 13.0       6.0        2.0       437.0  3631.0
# 2      11703.0                 13.0       6.0        2.0       437.0  3631.0
# 3      11703.0                 13.0       6.0        2.0       437.0  3631.0
# 4      11703.0                  4.0       6.0        4.0       437.0  3631.0
# ...        ...                  ...       ...        ...         ...     ...
# 8504   33031.0                  0.0       0.0        1.0      2277.0  3012.0
# 8505    3456.0                  1.0       8.0        2.0      2460.0  3663.0
# 8506     136.0                 62.0       8.0        2.0       310.0   118.0
# 8507   18393.0                  1.0       9.0        2.0      1159.0  1803.0
# 8508    6401.0                  1.0       0.0        2.0      3035.0  2107.0
#
#       episodes  favorites  user_id  Military  ...        90        91  \
# 0         13.0      508.0   135745         0  ...  0.001631  0.000190
# 1         13.0      508.0   135745         0  ...  0.001631  0.000190
# 2         13.0      508.0   135745         0  ...  0.001631  0.000190
# 3         13.0      508.0   135745         0  ...  0.001631  0.000190
# 4         13.0      508.0  2240579         0  ...  0.001631  0.000190
# ...        ...        ...      ...       ...  ...       ...       ...
# 8504      12.0       98.0  4403973         0  ...  0.002058 -0.004004
# 8505       1.0       24.0   182311         0  ...  0.001088 -0.001576
# 8506      62.0     5933.0  1109497         0  ...  0.001631  0.000190
# 8507       1.0      182.0  2128989         0  ...  0.001631  0.000190
# 8508       1.0       14.0   486647         0  ... -0.007426 -0.001064
#
#             92        93        94        95        96        97        98  \
# 0     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 1     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 2     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 3     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 4     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# ...        ...       ...       ...       ...       ...       ...       ...
# 8504 -0.008241  0.006278 -0.001949 -0.000666 -0.001771 -0.004536  0.004062
# 8505  0.002197 -0.007882 -0.002717  0.002663  0.005347 -0.002392 -0.009510
# 8506  0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 8507  0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 8508 -0.000795 -0.002563  0.009683 -0.000459  0.005874 -0.007448 -0.002506
#
#             99
# 0     0.006393
# 1     0.006393
# 2     0.006393
# 3     0.006393
# 4     0.006393
# ...        ...
# 8504 -0.004270
# 8505  0.004506
# 8506  0.006393
# 8507  0.006393
# 8508 -0.005550
#
# [8509 rows x 156 columns]

# %%
anime_df['user_id']
# Out:
# 0        135745
# 1        135745
# 2        135745
# 3        135745
# 4       2240579
#          ...
# 8504    4403973
# 8505     182311
# 8506    1109497
# 8507    2128989
# 8508     486647
# Name: user_id, Length: 8509, dtype: int64

# %%
anime_df.isnull().any()
# Out:
# anime_id               False
# my_watched_episodes    False
# my_score               False
# my_status              False
# popularity             False
#                        ...
# 95                     False
# 96                     False
# 97                     False
# 98                     False
# 99                     False
# Length: 156, dtype: bool

# %%
anime_df.corr()
# Out:
# /var/folders/y7/b9q8qz9942vb03jb76_vv3s80000gn/T/ipykernel_40806/1504362319.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   anime_df.corr()
#                      anime_id  my_watched_episodes  my_score  my_status  \
# anime_id             1.000000            -0.174423 -0.030382   0.010332
# my_watched_episodes -0.174423             1.000000  0.181909  -0.218465
# my_score            -0.030382             0.181909  1.000000  -0.631703
# my_status            0.010332            -0.218465 -0.631703   1.000000
# popularity           0.044969            -0.134058 -0.121875   0.117266
# ...                       ...                  ...       ...        ...
# 95                   0.074916             0.096142 -0.002787  -0.012489
# 96                   0.057214            -0.160701  0.031536  -0.007701
# 97                   0.069690            -0.167454  0.029718  -0.006943
# 98                   0.166202             0.025375 -0.018298  -0.002555
# 99                  -0.151328             0.051254 -0.005951   0.012365
#
#                      popularity      rank  episodes  favorites   user_id  \
# anime_id               0.044969  0.156113 -0.208335  -0.164427  0.273935
# my_watched_episodes   -0.134058 -0.089393  0.775073   0.212610 -0.045269
# my_score              -0.121875 -0.122014 -0.007578   0.090406 -0.047331
# my_status              0.117266  0.069176 -0.030758  -0.106407  0.088506
# popularity             1.000000  0.567707 -0.144762  -0.334823 -0.100148
# ...                         ...       ...       ...        ...       ...
# 95                     0.002789  0.063269  0.117404   0.071357  0.036024
# 96                    -0.021573  0.051865 -0.223654  -0.096295  0.022205
# 97                    -0.059384 -0.047184 -0.215555  -0.069502  0.042151
# 98                    -0.061672  0.078756  0.023566  -0.104842  0.050988
# 99                     0.019795 -0.183880  0.104650   0.154799 -0.044061
#
#                      Military  ...        90        91        92        93  \
# anime_id            -0.088600  ... -0.087806  0.164168  0.050260  0.062903
# my_watched_episodes -0.005504  ...  0.177852  0.080279 -0.134304  0.100750
# my_score             0.038707  ... -0.015916 -0.009901  0.024100 -0.050423
# my_status           -0.028906  ... -0.007165 -0.003286  0.003490  0.020381
# popularity          -0.039122  ...  0.057419  0.002321 -0.140349  0.027427
# ...                       ...  ...       ...       ...       ...       ...
# 95                   0.001210  ... -0.071901  0.581403  0.207579  0.196732
# 96                   0.019704  ... -0.483867  0.116166  0.154194 -0.762513
# 97                  -0.004439  ... -0.343136  0.088199  0.543090 -0.555009
# 98                  -0.198449  ... -0.341107  0.695192  0.488942  0.465902
# 99                   0.118077  ...  0.602387 -0.667363 -0.222838  0.238118
#
#                            94        95        96        97        98  \
# anime_id             0.000238  0.074916  0.057214  0.069690  0.166202
# my_watched_episodes  0.123139  0.096142 -0.160701 -0.167454  0.025375
# my_score            -0.021768 -0.002787  0.031536  0.029718 -0.018298
# my_status            0.001841 -0.012489 -0.007701 -0.006943 -0.002555
# popularity          -0.022447  0.002789 -0.021573 -0.059384 -0.061672
# ...                       ...       ...       ...       ...       ...
# 95                   0.421360  1.000000 -0.418140 -0.416990  0.273695
# 96                  -0.605873 -0.418140  1.000000  0.723285 -0.102821
# 97                  -0.397192 -0.416990  0.723285  1.000000  0.196642
# 98                   0.697092  0.273695 -0.102821  0.196642  1.000000
# 99                  -0.106174 -0.008644 -0.641777 -0.465281 -0.551358
#
#                            99
# anime_id            -0.151328
# my_watched_episodes  0.051254
# my_score            -0.005951
# my_status            0.012365
# popularity           0.019795
# ...                       ...
# 95                  -0.008644
# 96                  -0.641777
# 97                  -0.465281
# 98                  -0.551358
# 99                   1.000000
#
# [155 rows x 155 columns]

# %%
anime_df2 = anime_df.drop(['my_status', 'episodes', 'rank', 'popularity'], axis =1)
anime_df2
# Out:
#       anime_id  my_watched_episodes  my_score  favorites  user_id  Military  \
# 0      11703.0                 13.0       6.0      508.0   135745         0
# 1      11703.0                 13.0       6.0      508.0   135745         0
# 2      11703.0                 13.0       6.0      508.0   135745         0
# 3      11703.0                 13.0       6.0      508.0   135745         0
# 4      11703.0                  4.0       6.0      508.0  2240579         0
# ...        ...                  ...       ...        ...      ...       ...
# 8504   33031.0                  0.0       0.0       98.0  4403973         0
# 8505    3456.0                  1.0       8.0       24.0   182311         0
# 8506     136.0                 62.0       8.0     5933.0  1109497         0
# 8507   18393.0                  1.0       9.0      182.0  2128989         0
# 8508    6401.0                  1.0       0.0       14.0   486647         0
#
#       Supernatural  Adventure  Mecha  Sports  ...        90        91  \
# 0                1          0      0       0  ...  0.001631  0.000190
# 1                1          0      0       0  ...  0.001631  0.000190
# 2                1          0      0       0  ...  0.001631  0.000190
# 3                1          0      0       0  ...  0.001631  0.000190
# 4                1          0      0       0  ...  0.001631  0.000190
# ...            ...        ...    ...     ...  ...       ...       ...
# 8504             0          0      0       1  ...  0.002058 -0.004004
# 8505             0          0      0       0  ...  0.001088 -0.001576
# 8506             0          1      0       0  ...  0.001631  0.000190
# 8507             0          1      0       0  ...  0.001631  0.000190
# 8508             0          0      0       0  ... -0.007426 -0.001064
#
#             92        93        94        95        96        97        98  \
# 0     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 1     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 2     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 3     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 4     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# ...        ...       ...       ...       ...       ...       ...       ...
# 8504 -0.008241  0.006278 -0.001949 -0.000666 -0.001771 -0.004536  0.004062
# 8505  0.002197 -0.007882 -0.002717  0.002663  0.005347 -0.002392 -0.009510
# 8506  0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 8507  0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 8508 -0.000795 -0.002563  0.009683 -0.000459  0.005874 -0.007448 -0.002506
#
#             99
# 0     0.006393
# 1     0.006393
# 2     0.006393
# 3     0.006393
# 4     0.006393
# ...        ...
# 8504 -0.004270
# 8505  0.004506
# 8506  0.006393
# 8507  0.006393
# 8508 -0.005550
#
# [8509 rows x 152 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Label Encoding
le = LabelEncoder()


for col in anime_df2.select_dtypes(include='object').columns:
    anime_df2[col] = le.fit_transform(anime_df2[col].astype(str))

# %%
anime_df2
# Out:
#       anime_id  my_watched_episodes  my_score  favorites  user_id  Military  \
# 0      11703.0                 13.0       6.0      508.0   135745         0
# 1      11703.0                 13.0       6.0      508.0   135745         0
# 2      11703.0                 13.0       6.0      508.0   135745         0
# 3      11703.0                 13.0       6.0      508.0   135745         0
# 4      11703.0                  4.0       6.0      508.0  2240579         0
# ...        ...                  ...       ...        ...      ...       ...
# 8504   33031.0                  0.0       0.0       98.0  4403973         0
# 8505    3456.0                  1.0       8.0       24.0   182311         0
# 8506     136.0                 62.0       8.0     5933.0  1109497         0
# 8507   18393.0                  1.0       9.0      182.0  2128989         0
# 8508    6401.0                  1.0       0.0       14.0   486647         0
#
#       Supernatural  Adventure  Mecha  Sports  ...        90        91  \
# 0                1          0      0       0  ...  0.001631  0.000190
# 1                1          0      0       0  ...  0.001631  0.000190
# 2                1          0      0       0  ...  0.001631  0.000190
# 3                1          0      0       0  ...  0.001631  0.000190
# 4                1          0      0       0  ...  0.001631  0.000190
# ...            ...        ...    ...     ...  ...       ...       ...
# 8504             0          0      0       1  ...  0.002058 -0.004004
# 8505             0          0      0       0  ...  0.001088 -0.001576
# 8506             0          1      0       0  ...  0.001631  0.000190
# 8507             0          1      0       0  ...  0.001631  0.000190
# 8508             0          0      0       0  ... -0.007426 -0.001064
#
#             92        93        94        95        96        97        98  \
# 0     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 1     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 2     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 3     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 4     0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# ...        ...       ...       ...       ...       ...       ...       ...
# 8504 -0.008241  0.006278 -0.001949 -0.000666 -0.001771 -0.004536  0.004062
# 8505  0.002197 -0.007882 -0.002717  0.002663  0.005347 -0.002392 -0.009510
# 8506  0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 8507  0.003474  0.000218  0.009619  0.005061 -0.008917 -0.007042  0.000901
# 8508 -0.000795 -0.002563  0.009683 -0.000459  0.005874 -0.007448 -0.002506
#
#             99
# 0     0.006393
# 1     0.006393
# 2     0.006393
# 3     0.006393
# 4     0.006393
# ...        ...
# 8504 -0.004270
# 8505  0.004506
# 8506  0.006393
# 8507  0.006393
# 8508 -0.005550
#
# [8509 rows x 152 columns]

# %%
print(anime_df2.dtypes)
# Out:
# anime_id               float64
# my_watched_episodes    float64
# my_score               float64
# favorites              float64
# user_id                  int64
#                         ...
# 95                     float32
# 96                     float32
# 97                     float32
# 98                     float32
# 99                     float32
# Length: 152, dtype: object

# %%
svd_df = anime_df2.drop(['user_id'], axis =1 )

# %%
X = svd_df.values
mean = np.mean(X, axis = 0)
X_prime = X - mean

# %%
X_prime.shape
# Out:
# (8509, 151)

# %%
X_prime = X_prime.astype(float)

# %%
from scipy.linalg import svd
U,D,VT = svd(X_prime)

# %%
U.shape, D.shape, VT.shape
# Out:
# ((8509, 8509), (151,), (151, 151))

# %%
# Assuming q = 3
q = 3

U_q = U[:, :q]
D_q = D[:q]
VT_q = VT[:q, :]

# Compute the low-rank truncation of X_prime
X_prime_q = U_q @ np.diag(D_q) @ VT_q
X_prime_q
# Out:
# array([[ 1.24405083e+03, -3.62849826e+00, -1.72225057e-01, ...,
#          1.33065494e-04,  3.47175012e-04, -4.82157760e-04],
#        [ 1.24405083e+03, -3.62849826e+00, -1.72225057e-01, ...,
#          1.33065494e-04,  3.47175012e-04, -4.82157760e-04],
#        [ 1.24405083e+03, -3.62849826e+00, -1.72225057e-01, ...,
#          1.33065494e-04,  3.47175012e-04, -4.82157760e-04],
#        ...,
#        [-1.03229491e+04,  4.53861586e+01,  6.83389878e-01, ...,
#         -7.86738678e-04, -3.31469124e-04,  5.55542053e-04],
#        [ 7.93405080e+03, -1.55705197e+01, -3.55521689e-01, ...,
#          4.05291357e-04,  8.24253668e-04, -9.65162549e-04],
#        [-4.05794924e+03, -1.57293895e+01, -4.01100124e-01, ...,
#          2.39648787e-04, -2.26489266e-04, -1.31942660e-04]])

# %%
original_data = X_prime
reconstruct_data = X_prime_q

MSE = np.mean(np.sqrt((original_data - reconstruct_data)**2))

print("Error: ", MSE)
# Out:
# Error:  0.09442909368800786

# %% [markdown]
# The Error looks promising, for now

# %%
import numpy as np
from sklearn.cluster import KMeans

# perform k-means clustering on the low-rank approximation, 
#we could also do it manually I've posted the code on the last part
kmeans = KMeans(n_clusters=2, random_state=0).fit(reconstruct_data)

labels = kmeans.labels_
# Out:
# /Users/jforevers/opt/anaconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.metrics import silhouette_score

y_pred = labels

# Compute the silhouette score
score = silhouette_score(reconstruct_data, y_pred)
print("Silhouette score: ", score.round(2))
# Out:
# Silhouette score:  0.7

# %%
X
# Out:
# array([[ 1.17030000e+04,  1.30000000e+01,  6.00000000e+00, ...,
#         -7.04156049e-03,  9.01455875e-04,  6.39253389e-03],
#        [ 1.17030000e+04,  1.30000000e+01,  6.00000000e+00, ...,
#         -7.04156049e-03,  9.01455875e-04,  6.39253389e-03],
#        [ 1.17030000e+04,  1.30000000e+01,  6.00000000e+00, ...,
#         -7.04156049e-03,  9.01455875e-04,  6.39253389e-03],
#        ...,
#        [ 1.36000000e+02,  6.20000000e+01,  8.00000000e+00, ...,
#         -7.04156049e-03,  9.01455875e-04,  6.39253389e-03],
#        [ 1.83930000e+04,  1.00000000e+00,  9.00000000e+00, ...,
#         -7.04156049e-03,  9.01455875e-04,  6.39253389e-03],
#        [ 6.40100000e+03,  1.00000000e+00,  0.00000000e+00, ...,
#         -7.44758733e-03, -2.50607380e-03, -5.54986345e-03]])

# %% [markdown]
# ## Option 1: Pearson Correlation

# %%
import numpy as np
from sklearn.metrics.pairwise import pairwise_distances

# Compute the item-item similarity matrix using Pearson correlation
item_sim_matrix = np.corrcoef(X_prime_q.T)


weighted_ratings = item_sim_matrix.dot(X_prime_q.T)

weights = np.abs(item_sim_matrix).sum(axis=1)
weighted_ratings /= weights.reshape(-1, 1)

user_id = 10 # assuming the user ID is 10
recommended_items = np.argsort(weighted_ratings[:, user_id])[::-1][:10]

# %%
recommended_items
# Out:
# array([ 62,  79,   8, 128,  12, 118,  43,  28, 113,  47])

# %%
recommended_df = pd.DataFrame({'item_id': recommended_items, 'score': weighted_ratings[:, user_id][recommended_items]})

# Sort the DataFrame by score in descending order to get the top recommendations
recommended_df = recommended_df.sort_values(by='score', ascending=False)

final_df = pd.merge(recommended_df, small_df, how='inner', left_on='item_id', right_on='anime_id')
final_df.head(10)
# Out:
#    item_id       score        username  anime_id  my_watched_episodes  \
# 0       79  119.620144      mgviperman      79.0                 24.0
# 1       79  119.620144          Knek03      79.0                 24.0
# 2       79  119.620144            Onyx      79.0                 24.0
# 3       79  119.620144      romkersmen      79.0                 24.0
# 4       43  110.222152    RyoHazuki224      43.0                  1.0
# 5       43  110.222152      ghost4luck      43.0                  1.0
# 6       43  110.222152           Korru      43.0                  1.0
# 7       28  109.101936      Tsubasa-01      28.0                  0.0
# 8       47  101.579642       ErinCrowe      47.0                  1.0
# 9       47  101.579642  Sorglose_Genie      47.0                  1.0
#
#    my_score  my_status               title  \
# 0       8.0        2.0            Shuffle!
# 1       7.0        2.0            Shuffle!
# 2       8.0        2.0            Shuffle!
# 3      10.0        2.0            Shuffle!
# 4       6.0        2.0  Ghost in the Shell
# 5      10.0        2.0  Ghost in the Shell
# 6       8.0        2.0  Ghost in the Shell
# 7       0.0        6.0    Yakitate!! Japan
# 8      10.0        2.0               Akira
# 9       9.0        2.0               Akira
#
#                                                genre        source  \
# 0  Comedy, Drama, Ecchi, Fantasy, Harem, Magic, R...  Visual novel
# 1  Comedy, Drama, Ecchi, Fantasy, Harem, Magic, R...  Visual novel
# 2  Comedy, Drama, Ecchi, Fantasy, Harem, Magic, R...  Visual novel
# 3  Comedy, Drama, Ecchi, Fantasy, Harem, Magic, R...  Visual novel
# 4  Action, Sci-Fi, Police, Psychological, Mecha, ...         Manga
# 5  Action, Sci-Fi, Police, Psychological, Mecha, ...         Manga
# 6  Action, Sci-Fi, Police, Psychological, Mecha, ...         Manga
# 7                                    Comedy, Shounen         Manga
# 8  Action, Military, Sci-Fi, Adventure, Horror, S...         Manga
# 9  Action, Military, Sci-Fi, Adventure, Horror, S...         Manga
#
#    popularity    rank   type  episodes  favorites  user_id
# 0       395.0  2666.0     TV      24.0     1482.0    18999
# 1       395.0  2666.0     TV      24.0     1482.0     3611
# 2       395.0  2666.0     TV      24.0     1482.0    76079
# 3       395.0  2666.0     TV      24.0     1482.0   197779
# 4       174.0   192.0  Movie       1.0     7755.0   132802
# 5       174.0   192.0  Movie       1.0     7755.0   488533
# 6       174.0   192.0  Movie       1.0     7755.0    24631
# 7      1301.0   540.0     TV      69.0      748.0  1660839
# 8       198.0   352.0  Movie       1.0     5029.0  1196271
# 9       198.0   352.0  Movie       1.0     5029.0   450134

# %% [markdown]
# ## Option 1: Cosine Similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Compute the item-item similarity matrix
item_sim_matrix = np.corrcoef(X_prime_q.T)

user_ratings = reconstruct_data[:, ].reshape(-1, 1)

weights = np.abs(item_sim_matrix).sum(axis=1)
weighted_ratings /= weights.reshape(-1, 1)

recommended_items = np.argsort(weighted_ratings.flatten())[::-1][:10]

# %%
recommended_items
# Out:
# array([638968, 638971, 638950, 638973, 638947, 638946, 638967, 638948,
#        638949, 638952])

# %% [markdown]
# ## K Nearest Neighbour

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics.pairwise import cosine_distances, cosine_similarity

# Compute the item-item similarity matrix
item_sim_matrix = cosine_similarity(reconstruct_data.T)

# Create a NearestNeighbors model using the item-item similarity matrix
model_knn = NearestNeighbors(metric='cosine', algorithm='brute')
model_knn.fit(reconstruct_data.T)

k = 10 # number of nearest neighbors to consider
item_indices = model_knn.kneighbors(return_distance=False, n_neighbors=k)

weights = item_sim_matrix.sum(axis=1).reshape(-1, 1)
weighted_ratings = item_sim_matrix.T.dot(reconstruct_data.T) / weights

user_id = 300  # assuming the user ID is 300
recommended_items = np.argsort(weighted_ratings[:, user_id])[::-1][:10]

# %%
recommended_items
# Out:
# array([  3,  45,  39,  43, 104,  65,  88,  98, 100,  68])

# %%
recommended_df = pd.DataFrame({'item_id': recommended_items, 'score': weighted_ratings[:, user_id][recommended_items]})

# Sort the DataFrame by score in descending order to get the top recommendations
recommended_df = recommended_df.sort_values(by='score', ascending=False)
final_df = pd.merge(recommended_df, small_df, how='inner', left_on='item_id', right_on='anime_id')

final_df.head(10)
# Out:
#    item_id         score       username  anime_id  my_watched_episodes  \
# 0       45  55690.612470      MirukiSan      45.0                 94.0
# 1       45  55690.612470        gokalex      45.0                 94.0
# 2       45  55690.612470       ladykanu      45.0                 94.0
# 3       43  25416.749402   RyoHazuki224      43.0                  1.0
# 4       43  25416.749402     ghost4luck      43.0                  1.0
# 5       43  25416.749402          Korru      43.0                  1.0
# 6      104  13046.835115      Jess-chan     104.0                 24.0
# 7      104  13046.835115       irishtea     104.0                 24.0
# 8       65  11036.718701        Shinino      65.0                 12.0
# 9       98   5356.551027  dontthinklive      98.0                 26.0
#
#    my_score  my_status                                    title  \
# 0      10.0        2.0  Rurouni Kenshin: Meiji Kenkaku Romantan
# 1       9.0        2.0  Rurouni Kenshin: Meiji Kenkaku Romantan
# 2       8.0        2.0  Rurouni Kenshin: Meiji Kenkaku Romantan
# 3       6.0        2.0                       Ghost in the Shell
# 4      10.0        2.0                       Ghost in the Shell
# 5       8.0        2.0                       Ghost in the Shell
# 6       9.0        2.0                          Ayashi no Ceres
# 7       9.0        2.0                          Ayashi no Ceres
# 8       0.0        2.0                   Rozen Maiden: Träumend
# 9       8.0        2.0                                 Mai-HiME
#
#                                                genre    source  popularity  \
# 0  Action, Adventure, Comedy, Historical, Romance...     Manga       240.0
# 1  Action, Adventure, Comedy, Historical, Romance...     Manga       240.0
# 2  Action, Adventure, Comedy, Historical, Romance...     Manga       240.0
# 3  Action, Sci-Fi, Police, Psychological, Mecha, ...     Manga       174.0
# 4  Action, Sci-Fi, Police, Psychological, Mecha, ...     Manga       174.0
# 5  Action, Sci-Fi, Police, Psychological, Mecha, ...     Manga       174.0
# 6  Adventure, Comedy, Horror, Psychological, Supe...     Manga      1677.0
# 7  Adventure, Comedy, Horror, Psychological, Supe...     Manga      1677.0
# 8               Action, Comedy, Drama, Magic, Seinen     Manga      1028.0
# 9  Action, Comedy, Drama, Fantasy, Magic, Mecha, ...  Original       986.0
#
#      rank   type  episodes  favorites  user_id
# 0   168.0     TV      94.0     8137.0  1444121
# 1   168.0     TV      94.0     8137.0   287507
# 2   168.0     TV      94.0     8137.0    79253
# 3   192.0  Movie       1.0     7755.0   132802
# 4   192.0  Movie       1.0     7755.0   488533
# 5   192.0  Movie       1.0     7755.0    24631
# 6  2267.0     TV      24.0      486.0    32130
# 7  2267.0     TV      24.0      486.0    39695
# 8  1024.0     TV      12.0      471.0   380640
# 9  1500.0     TV      26.0     1205.0    80711

# %%
import pandas as pd

def get_recommendations(data_list):
    anime_df = pd.read_csv('animelist.csv')

    merged_df = pd.merge(data_list, anime_df, on='anime_id')
    
    columns_to_keep = ['anime_id', 'Name', 'Score', 'Type', 'Source', 'Synopsis']
    recommended_anime = merged_df[columns_to_keep]
    
    recommended_anime = recommended_anime.iloc[recommended_items][:10]

    return recommended_anime

# %%
recommended_df.to_csv('recommended_anime.csv', index=False)

# %%
#recommended_df = recommended_df(data)

# %%
#Complete Code
# def euclidean_dissimilarity(a, b):
#     return np.linalg.norm(a - b)

# def random_vectors(Matrix_X, K):
#     return Matrix_X[np.random.choice(Matrix_X.shape[0], K, replace=False), :]

# def assign_cluster(x_i, dissimilarity, mean_vectors):
#     min_dissimilarity = float("inf")
#     best_cluster = -2
    
#     for k, mean_vector in enumerate(mean_vectors):
#         cur_dissimilarity = dissimilarity(x_i, mean_vector)
#         if cur_dissimilarity < min_dissimilarity:
#             min_dissimilarity = cur_dissimilarity
#             best_cluster = k
#     return best_cluster

# def k_means(X_Matrix, K, dissimilarity, mean_vectors=None, max_iters=500):
#     N = X_Matrix.shape[0]
#     if mean_vectors is None:
#         mean_vectors = random_vectors(X_Matrix, K)
#     labels = np.zeros(N)
    
#     for i in range(max_iters):
#         for j in range(N):
#             labels[j] = assign_cluster(X_Matrix[j], dissimilarity, mean_vectors)
            
#         for k in range(K):
#             mean_vectors[k] = np.mean(X_Matrix[labels == k], axis=0)
            
#     return labels, mean_vectors

# K = 2
# labels, means = k_means(projected_data, K, euclidean_dissimilarity)
